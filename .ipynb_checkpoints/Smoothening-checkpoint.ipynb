# %%
import numpy as np
import matplotlib.pyplot as plt
import pymks
import numpy as np
from PIL import Image
from Scripts import SpatialCorrelations as corr
import matplotlib.pyplot as plt
import pandas as pd
import os
from Scripts import velocityCalculations as vel

# %%
path = '/Users/adithyaiyer/Desktop/TimeSeries/'
list_files = os.listdir(path)
list_files.sort()
j = 0
for i in list_files:
    list_files[j] = path+i
    j = j+1
    
img_ = corr.dat_to_numpy(list_files[190])
plt.imshow(img_)
plt.colorbar()
plt.show()
print(np.sum(img_))
# Out:
# 419430.6448388482

# %%
#img_ = (img_>0.5)*1
img = img_-0.5
plt.imshow(img)
plt.colorbar()

# %%
for i in range(1000):
    if i%100==0:
        print(i)
    S = img/(np.sqrt(1+img*img))
    G = 1-vel.gradientMagnitude(img)
    deltaTau = 0.01
    img = img+deltaTau*S*G
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
plt.imshow(img/20)
plt.colorbar()

# %%
plt.imshow(S)
