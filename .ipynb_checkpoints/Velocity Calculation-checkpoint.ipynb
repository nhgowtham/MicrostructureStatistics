.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_027900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_028000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_028100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_028200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_028300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_028400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_028500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_028600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_028700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_028800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_028900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_029000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_029100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_029200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_029300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_029400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_029500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_029600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_029700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_029800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_029900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_030000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_030100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_030200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_030300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_030400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_030500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_030600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_030700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_030800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_030900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_031000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_031100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_031200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_031300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_031400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_031500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_031600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_031700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_031800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_031900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_032000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_032100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_032200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_032300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_032400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_032500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_032600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_032700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_032800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_032900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_033000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_033100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_033200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_033300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_033400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_033500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_033600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_033700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_033800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_033900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_034000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_034100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_034200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_034300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_034400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_034500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_034600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_034700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_034800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_034900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_035000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_035100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_035200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_035300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_035400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_035500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_035600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_035700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_035800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_035900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_036000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_036100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_036200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_036300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_036400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_036500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_036600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_036700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_036800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_036900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_037000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_037100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_037200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_037300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_037400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_037500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_037600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_037700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_037800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_037900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_038000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_038100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_038200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_038300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_038400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_038500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_038600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_038700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_038800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_038900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_039000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_039100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_039200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_039300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_039400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_039500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_039600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_039700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_039800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_039900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_040000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_040100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_040200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_040300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_040400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_040500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_040600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_040700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_040800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_040900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_041000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_041100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_041200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_041300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_041400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_041500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_041600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_041700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_041800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_041900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_042000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_042100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_042200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_042300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_042400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_042500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_042600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_042700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_042800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_042900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_043000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_043100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_043200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_043300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_043400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_043500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_043600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_043700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_043800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_043900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_044000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_044100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_044200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_044300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_044400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_044500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_044600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_044700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_044800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_044900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_045000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_045100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_045200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_045300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_045400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_045500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_045600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_045700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_045800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_045900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_046000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_046100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_046200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_046300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_046400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_046500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_046600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_046700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_046800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_046900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_047000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_047100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_047200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_047300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_047400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_047500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_047600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_047700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_047800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_047900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_048000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_048100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_048200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_048300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_048400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_048500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_048600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_048700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_048800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_048900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_049000.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_049100.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_049200.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_049300.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_049400.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_049500.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_049600.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_049700.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_049800.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_049900.dat',
#  '/home/sushil/Desktop/AC/ac2d/time_050000.dat']

# %%
# For circular only 0:400 will do
img_ = corr.dat_to_numpy(list_files[400])
img_ = vel.gaussian_filter(img_,4)
img_ = (img_>0.5)*1

plt.imshow(img_)
plt.colorbar()
plt.title('Original Binary image')
plt.show()
print(np.sum(img_))
# Out:
# 1969

# %%
velocity = vel.velocityMagnitude(list_files, 100, 3)
velocity1 = vel.velocityDirection(list_files, 100, 3)

# %%
x = np.zeros((128,128))
y = np.zeros((128,128))
M = np.zeros((128,128))           
for i in range(0,128):
    for j in range(0,128):
        if np.max(velocity1[0][i*4:(i+1)*4,j*4:(j+1)*4])==0.0:
            x[i][j] = np.min(velocity1[0][i*4:(i+1)*4,j*4:(j+1)*4])
        else:
            x[i][j] = np.max(velocity1[0][i*4:(i+1)*4,j*4:(j+1)*4])
        if np.max(velocity1[1][i*4:(i+1)*4,j*4:(j+1)*4])==0.0:
            y[i][j] = np.min(velocity1[1][i*4:(i+1)*4,j*4:(j+1)*4])
        else:
            y[i][j] = np.max(velocity1[1][i*4:(i+1)*4,j*4:(j+1)*4])   


for i in range(0,128):
    for j in range(0,128):
        if np.max(velocity[i*4:(i+1)*4,j*4:(j+1)*4])==0.0:
            M[i][j] = np.min(velocity[i*4:(i+1)*4,j*4:(j+1)*4])
        else:
            M[i][j] = np.max(velocity[i*4:(i+1)*4,j*4:(j+1)*4])


y = y*np.sign(M)
x = x*np.sign(M)
Fx = y
Fy = x
x_ = np.arange(0,128)
y_ = np.arange(0,128)
        
X, Y = np.meshgrid(x_,y_)

#plt.axes([0.065, 0.065, 0.9, 0.9])
plt.rcParams["figure.figsize"] = (20,20)
qq =plt.quiver(X, Y, Fx, Fy,np.abs(M),scale = 16,cmap=plt.cm.cool)
plt.colorbar(qq,cmap=plt.cm.jet)
plt.title('Velocity plot in pixels per time frame')
plt.show()

# %%
# For calculating radial distribution
# A =[]
# B = []
# for i in range(1,50):
#     A.append(vel.radiusCircular(list_files,9*i, 2))
#     B.append(9*i)
    
# plt.plot(B,A)
# plt.xlabel('timestep')
# plt.ylabel('radius in pixels')

# %%
circularVelocity = vel.velocityCircular(list_files,100, 3)
print(circularVelocity)
# Out:
# velocity in pixels per frame =  -0.17413873068457994
# -0.17413873068457994

# %%
plt.rcParams["figure.figsize"] = (8,8)
plt.imshow(velocity)
plt.colorbar()

print('max velocity = ',np.min(velocity))
# Out:
# max velocity =  -0.17574528838173512

# %%
X = []
for i in range(velocity.shape[0]):
    for j in range(velocity.shape[1]):
        if velocity[i][j]!=0 :
            X.append(velocity[i][j])

# %%
np.min(X)
# Out:
# -0.17574528838173512

# %%
Circular = []
Interface = []
t = []
for l in range(50):
    Circular.append(vel.velocityCircular(list_files,l*8, 2))
    interfacevelocityAll = vel.velocityMagnitude(list_files, l*8, 2)

    X = []
    for i in range(interfacevelocityAll.shape[0]):
        for j in range(interfacevelocityAll.shape[1]):
            if interfacevelocityAll[i][j]!=0 :
                X.append(interfacevelocityAll[i][j])
    Interface.append(np.median(X))
    t.append(l*8)
# Out:
# velocity in pixels per frame =  36.830834435035
# velocity in pixels per frame =  -0.15061471820677852
# velocity in pixels per frame =  -0.15336001924531809
# velocity in pixels per frame =  -0.1556569244933783
# velocity in pixels per frame =  -0.15741676896453308
# velocity in pixels per frame =  -0.15907653924616896
# velocity in pixels per frame =  -0.16113520984536223
# velocity in pixels per frame =  -0.16310947292839076
# velocity in pixels per frame =  -0.16472267882427025
# velocity in pixels per frame =  -0.1667669701681843
# velocity in pixels per frame =  -0.16895743109083364
# velocity in pixels per frame =  -0.17073884125265928
# velocity in pixels per frame =  -0.17306146038816314
# velocity in pixels per frame =  -0.17529862262343698
# velocity in pixels per frame =  -0.17742385739089883
# velocity in pixels per frame =  -0.18007516848671182
# velocity in pixels per frame =  -0.1822906819727764
# velocity in pixels per frame =  -0.18514143632776955
# velocity in pixels per frame =  -0.1876063139607318
# velocity in pixels per frame =  -0.19065953115359946
# velocity in pixels per frame =  -0.1933861667568646
# velocity in pixels per frame =  -0.1966957059685607
# velocity in pixels per frame =  -0.19976948250787294
# velocity in pixels per frame =  -0.2032531210527857
# velocity in pixels per frame =  -0.20690159796712257
# velocity in pixels per frame =  -0.21055101103198778
# velocity in pixels per frame =  -0.2146254205083474
# velocity in pixels per frame =  -0.2189240727985068
# velocity in pixels per frame =  -0.2233637398797471
# velocity in pixels per frame =  -0.2281113207820796
# velocity in pixels per frame =  -0.23323339922015643
# velocity in pixels per frame =  -0.23872227428158688
# velocity in pixels per frame =  -0.24460086670384365
# velocity in pixels per frame =  -0.2509257385804915
# velocity in pixels per frame =  -0.25776996252293455
# velocity in pixels per frame =  -0.26521999754579006
# velocity in pixels per frame =  -0.27336332286225346
# velocity in pixels per frame =  -0.2822532061359091
# velocity in pixels per frame =  -0.2920324048974834
# velocity in pixels per frame =  -0.3030988011472253
# velocity in pixels per frame =  -0.31529208714881446
# velocity in pixels per frame =  -0.32933129188651505
# velocity in pixels per frame =  -0.34514544135565534
# velocity in pixels per frame =  -0.3636356575808482
# velocity in pixels per frame =  -0.3854927361041642
# velocity in pixels per frame =  -0.41184992352115063
# velocity in pixels per frame =  -0.44449709098173934
# velocity in pixels per frame =  -0.4862540506220503
# velocity in pixels per frame =  -0.5425875464284236
# velocity in pixels per frame =  -0.6246061302280683

# %%
plt.rcParams["figure.figsize"] = (10,10)
plt.plot(t[2:], Circular[2:],'r',label ='Circular')
plt.plot(t[2:], Interface[2:],'b',label ='Interface')

plt.title('Velocity vs time')
plt.legend()
plt.xlabel('time')
plt.ylabel('velocity')
plt.show()

# %%
rad = []
for l in range(50):
    rad.append(vel.radiusCircular(list_files,l*8, 2))

# %%
inverseVelocity =1/(np.array(Interface))
inverseVelocity=np.abs(inverseVelocity).tolist()
plt.plot(rad[2:],inverseVelocity[2:] ,'b',label ='Interface')
plt.title('radius vs 1/velocity')
plt.xlabel('radius (pixels)')
plt.ylabel('1/velocity (time/pixel)')
# Out:
# Text(0, 0.5, '1/velocity (time/pixel)')

# %%
inverseRad =1/(np.array(rad))
inverseRad=inverseRad.tolist()
plt.plot(inverseRad[2:], np.abs(np.array(Interface)),'b',label ='Interface')
plt.title('1/radius vs velocity')
plt.xlabel('1/radius (1/pixels)')
plt.ylabel('velocity (pixel/time)')
# Out:
# Text(0, 0.5, 'velocity (pixel/time)')
