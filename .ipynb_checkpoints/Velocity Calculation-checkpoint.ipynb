# %%
import pymks
import numpy as np
from PIL import Image
from Scripts import SpatialCorrelations as corr
import matplotlib.pyplot as plt
import pandas as pd
import os
from Scripts import velocityCalculations as vel
# Out:
# /home/sushil/anaconda3/envs/env_adi/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/sushil/anaconda3/envs/env_adi/lib/python3.6/site-packages/sklearn/learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %%
path = '/home/sushil/Desktop/CH/output/'
list_of_files = os.listdir(path)
list_of_files.sort()
list_files = []
for i in list_of_files:
    if i[-5:]=='0.dat':
        list_files.append(path+i)

# %%
(list_files)
# Out:
# ['/home/sushil/Desktop/CH/output/time_000100.dat',
#  '/home/sushil/Desktop/CH/output/time_000200.dat',
#  '/home/sushil/Desktop/CH/output/time_000300.dat',
#  '/home/sushil/Desktop/CH/output/time_000400.dat',
#  '/home/sushil/Desktop/CH/output/time_000500.dat',
#  '/home/sushil/Desktop/CH/output/time_000600.dat',
#  '/home/sushil/Desktop/CH/output/time_000700.dat',
#  '/home/sushil/Desktop/CH/output/time_000800.dat',
#  '/home/sushil/Desktop/CH/output/time_000900.dat',
#  '/home/sushil/Desktop/CH/output/time_001000.dat',
#  '/home/sushil/Desktop/CH/output/time_001100.dat',
#  '/home/sushil/Desktop/CH/output/time_001200.dat',
#  '/home/sushil/Desktop/CH/output/time_001300.dat',
#  '/home/sushil/Desktop/CH/output/time_001400.dat',
#  '/home/sushil/Desktop/CH/output/time_001500.dat',
#  '/home/sushil/Desktop/CH/output/time_001600.dat',
#  '/home/sushil/Desktop/CH/output/time_001700.dat',
#  '/home/sushil/Desktop/CH/output/time_001800.dat',
# ...

# %%
img_ = corr.dat_to_numpy(list_files[1999])
plt.imshow(img_)
plt.colorbar()
plt.show()
print(np.sum(img_))
# Out:
# 78643.196846063

# %%
velocity = vel.velocityMagnitude(list_files, 1000, 3)
velocity1 = vel.velocityDirection(list_files, 1000, 3)

# %%
x = np.zeros((128,128))
y = np.zeros((128,128))
M = np.zeros((128,128))           
for i in range(0,128):
    for j in range(0,128):
        if np.max(velocity1[0][i*4:(i+1)*4,j*4:(j+1)*4])==0.0:
            x[i][j] = np.min(velocity1[0][i*4:(i+1)*4,j*4:(j+1)*4])
        else:
            x[i][j] = np.max(velocity1[0][i*4:(i+1)*4,j*4:(j+1)*4])
        if np.max(velocity1[1][i*4:(i+1)*4,j*4:(j+1)*4])==0.0:
            y[i][j] = np.min(velocity1[1][i*4:(i+1)*4,j*4:(j+1)*4])
        else:
            y[i][j] = np.max(velocity1[1][i*4:(i+1)*4,j*4:(j+1)*4])   


for i in range(0,128):
    for j in range(0,128):
        if np.max(velocity[i*4:(i+1)*4,j*4:(j+1)*4])==0.0:
            M[i][j] = np.min(velocity[i*4:(i+1)*4,j*4:(j+1)*4])
        else:
            M[i][j] = np.max(velocity[i*4:(i+1)*4,j*4:(j+1)*4])


y = y*np.sign(M)
x = x*np.sign(M)
Fx = y
Fy = x
x_ = np.arange(0,128)
y_ = np.arange(0,128)
        
X, Y = np.meshgrid(x_,y_)

#plt.axes([0.065, 0.065, 0.9, 0.9])
plt.rcParams["figure.figsize"] = (20,20)
qq =plt.quiver(X, Y, Fx, Fy,M,scale = 16,cmap=plt.cm.jet)
plt.colorbar(qq,cmap=plt.cm.jet)
plt.title('Velocity plot in pixels per time frame')
plt.show()

# %%
# For calculating radial distribution
# A =[]
# B = []
# for i in range(1,50):
#     A.append(vel.radiusCircular(list_files,9*i, 2))
#     B.append(9*i)
    
# plt.plot(B,A)
# plt.xlabel('timestep')
# plt.ylabel('radius in pixels')

# %%
np.sign(np.array([[14,-12,3],[2,3,-2]]))
# Out:
# array([[ 1, -1,  1],
#        [ 1,  1, -1]])

# %%
circularVelocity = vel.velocityCircular(list_files,390, 3)
print(circularVelocity)
# Out:
# velocity in pixels per frame =  -0.6006155919524853
# -0.6006155919524853

# %%
plt.imshow(velocity)
plt.colorbar()

print('max velocity = ',np.min(velocity))
# Out:
# max velocity =  -0.6174555351600293

# %%
X = []
for i in range(velocity.shape[0]):
    for j in range(velocity.shape[1]):
        if velocity[i][j]!=0 :
            X.append(velocity[i][j])

# %%
np.min(X)
# Out:
# -0.6174555351600293

# %%
Circular = []
Interface = []
t = []
for l in range(40):
    Circular.append(vel.velocityCircular(list_files,10+10*l, 2))
    interfacevelocityAll = vel.velocityMagnitude(list_files, 10+10*l, 2)

    X = []
    for i in range(interfacevelocityAll.shape[0]):
        for j in range(interfacevelocityAll.shape[1]):
            if interfacevelocityAll[i][j]!=0 :
                X.append(interfacevelocityAll[i][j])
    Interface.append(np.median(X))
    t.append(10+10*l)
# Out:
# velocity in pixels per frame =  -0.15161331814960377
# velocity in pixels per frame =  -0.15432543223877815
# velocity in pixels per frame =  -0.15708974121302668
# velocity in pixels per frame =  -0.15907653924616896
# velocity in pixels per frame =  -0.16169842049005703
# velocity in pixels per frame =  -0.16388242488814578
# velocity in pixels per frame =  -0.1661840508031478
# velocity in pixels per frame =  -0.16895743109083364
# velocity in pixels per frame =  -0.17141609744357447
# velocity in pixels per frame =  -0.17396764150896496
# velocity in pixels per frame =  -0.176966084497991
# velocity in pixels per frame =  -0.18007516848671182
# velocity in pixels per frame =  -0.18313707533785717
# velocity in pixels per frame =  -0.18630725814656893
# velocity in pixels per frame =  -0.1897182640431249
# velocity in pixels per frame =  -0.1933861667568646
# velocity in pixels per frame =  -0.1972913921882693
# velocity in pixels per frame =  -0.20143317209514203
# ...

# %%
plt.plot(t, Circular,'r',label ='Circular')
plt.plot(t, Interface,'b',label ='Interface')
plt.rcParams["figure.figsize"] = (20,3)
plt.title('Velocity vs time')
plt.legend()
plt.xlabel('time')
plt.ylabel('velocity')
plt.show()

# %%
plt.plot(t, (np.array(Interface)-np.array(Circular))/np.array(Circular)*100,'r')

plt.rcParams["figure.figsize"] = (20,10)
plt.title('% Error in Velocity of interface with benchmark')
plt.show()

# %%
rad = []
for l in range(40):
    rad.append(vel.radiusCircular(list_files,10+10*l, 3))

# %%
plt.plot((np.array(rad)), 1/((np.array(Interface))*(np.array(Interface))),'b',label ='Interface')
plt.title('radius vs 1/velocity^2')
plt.xlabel('radius (pixels)')
plt.ylabel('1/velocity^2 (time^2/pixel^2)')
# Out:
# Text(0, 0.5, '1/velocity^2 (time^2/pixel^2)')

# %%
plt.plot(1/(np.array(rad)*np.array(rad)), (np.array(Interface)),'b',label ='Interface')
plt.title('1/radius^2 vs velocity')
plt.xlabel('1/radius^2 (1/pixels)')
plt.ylabel('velocity (pixel/time)')
# Out:
# Text(0, 0.5, 'velocity (pixel/time)')
