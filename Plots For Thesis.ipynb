# %%
import numpy as np
import pandas as pd
from Scripts import plots as p
from matplotlib import pyplot as plt

# %%
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/'

# %%
ls
# Out:
# '2 point correlations example.ipynb'
# 'Everything for circular spinodal,C04.ipynb'
# 'Everything for circular spinodal,C05.ipynb'
# 'Everything for circular spinodal,trial 1.ipynb'
# 'Everything for circular spinodal,trial 2.ipynb'
# 'Everything for circular spinodal,trial 3.ipynb'
# 'Everything for circular spinodal,trial 4 Backwards.ipynb'
# 'Everything_for_circular spinodal_trial_3.pkl'
# 'Everything_for_circular spinodal_trial_3_eig.npy'
#  Everything_for_circular_spinodal_C04.pkl
#  Everything_for_circular_spinodal_C04_eigenVectors.npy
#  Everything_for_circular_spinodal_C05.pkl
#  Everything_for_circular_spinodal_C05_eigenVectors.npy
#  Everything_for_circular_spinodal_trial_2_directional_growth.pkl
#  Everything_for_circular_spinodal_trial_2_directional_growth_eig.npy
# 'Hoshen Kopleman.ipynb'
# 'Plots For Thesis.ipynb'
#  Scripts/
# 'Smoothening, Contouring.ipynb'
# 'Time Series Calculation of Data.ipynb'
# 'Velocity Calculation.ipynb'
# ...

# %%
df1 = pd.read_pickle(path+'Everything_for_circular_spinodal_trial_2_directional_growth.pkl')
np1 = np.load(path+'Everything_for_circular_spinodal_trial_2_directional_growth_eig.npy')

# %%
p.plotFromDataOnlyY(df1['area'],title='Area',xlabel='Time',ylabel='Area')
p.plotFromDataOnlyY(df1['cog1'],title='Cog along y',xlabel='Time',ylabel='Cog along y')
p.plotFromDataOnlyY(df1['cog2'],title='Cog along x',xlabel='Time',ylabel='Cog along x')
p.plotFromDataOnlyY(np.array(df1['l_array'])/np.array(df1['b_array']),title='length/breadth',xlabel='Time',ylabel='l/b')
p.plotFromDataOnlyY(df1['theta_array'],title='Angle of Inclination',xlabel='Time',ylabel='Angle')
p.plotFromDataOnlyY(df1['numberOfPpts'],title='No of Precipitates',xlabel='Time',ylabel='No of Ppts')
# Out:
# True

# %%
df1 = pd.read_pickle(path+'Everything_for_circular spinodal_trial_3.pkl')
np1 = np.load(path+'Everything_for_circular spinodal_trial_3_eig.npy')
p.plotFromDataOnlyY(df1['area'],title='Area',xlabel='Time',ylabel='Area')
p.plotFromDataOnlyY(df1['cog1'],title='Cog along y',xlabel='Time',ylabel='Cog along y')
p.plotFromDataOnlyY(df1['cog2'],title='Cog along x',xlabel='Time',ylabel='Cog along x')
p.plotFromDataOnlyY(np.array(df1['l_array'])/np.array(df1['b_array']),title='length/breadth',xlabel='Time',ylabel='l/b')
p.plotFromDataOnlyY(df1['theta_array'],title='Angle of Inclination',xlabel='Time',ylabel='Angle')
p.plotFromDataOnlyY(df1['numberOfPpts'],title='No of Precipitates',xlabel='Time',ylabel='No of Ppts')
# Out:
# True

# %%
df1 = pd.read_pickle(path+'Everything_for_circular_spinodal_C04.pkl')
np1 = np.load(path+'Everything_for_circular_spinodal_C04_eigenVectors.npy')
area = df1['area'].tolist()
cog1 = df1['cog1'].tolist()
cog2 = df1['cog2'].tolist()
theta_array = df1['theta_array'].tolist()
numberOfPpts = df1['numberOfPpts'].tolist()

area.reverse()
cog1.reverse()
cog2.reverse()
numberOfPpts.reverse()
theta_array.reverse()



lb = np.flipud(np.array((df1['l_array'])/np.array(df1['b_array']))) 
p.plotFromDataOnlyY(area,title='Area',xlabel='Time',ylabel='Area')
p.plotFromDataOnlyY(cog1,title='Cog along y',xlabel='Time',ylabel='Cog along y')
p.plotFromDataOnlyY(cog2,title='Cog along x',xlabel='Time',ylabel='Cog along x')
p.plotFromDataOnlyY(lb,title='length/breadth',xlabel='Time',ylabel='l/b')
p.plotFromDataOnlyY(theta_array,title='Angle of Inclination',xlabel='Time',ylabel='Angle')
p.plotFromDataOnlyY(numberOfPpts,title='No of Precipitates',xlabel='Time',ylabel='No of Ppts')
# Out:
# True

# %%
df1 = pd.read_pickle(path+'Everything_for_circular_spinodal_C05.pkl')
np1 = np.load(path+'Everything_for_circular_spinodal_C05_eigenVectors.npy')
area = df1['area'].tolist()
cog1 = df1['cog1'].tolist()
cog2 = df1['cog2'].tolist()
theta_array = df1['theta_array'].tolist()
numberOfPpts = df1['numberOfPpts'].tolist()

area.reverse()
cog1.reverse()
cog2.reverse()
numberOfPpts.reverse()
theta_array.reverse()



lb = np.flipud(np.array((df1['l_array'])/np.array(df1['b_array']))) 
p.plotFromDataOnlyY(area,title='Area',xlabel='Time',ylabel='Area')
p.plotFromDataOnlyY(cog1,title='Cog along y',xlabel='Time',ylabel='Cog along y')
p.plotFromDataOnlyY(cog2,title='Cog along x',xlabel='Time',ylabel='Cog along x')
p.plotFromDataOnlyY(lb,title='length/breadth',xlabel='Time',ylabel='l/b')
p.plotFromDataOnlyY(theta_array,title='Angle of Inclination',xlabel='Time',ylabel='Angle')
p.plotFromDataOnlyY(numberOfPpts,title='No of Precipitates',xlabel='Time',ylabel='No of Ppts')
# Out:
# True
