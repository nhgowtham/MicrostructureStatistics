# %%
import numpy as np
from PIL import Image
from Scripts import SpatialCorrelations as corr
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pymks
import pandas as pd
import os
from Scripts import velocityCalculations as vel
from Scripts import hoshenKopleman as hosh
import math
import time
from numpy import linalg as LA
from Scripts import plots

# %%
# C=4
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/HexagonalPlotData2/'
microStrNoList_04 = np.load(path+'microStrNoList_04.npy')
pptNoList_04 = np.load(path+'pptNoList_04.npy')
autoCorr_04 = np.load(path+'autoCorr_04.npy')
autocorr060_04 = np.load(path+'autocorr060_04.npy')
autocorr3090_4 = np.load(path+'autocorr3090_4.npy')
areaDistList_4 = np.load(path+'areaDistList_4.npy',allow_pickle=True)

# C=5
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/HexagonalPlotData2/'

microStrNoList_05 = np.load(path+'microStrNoList_05.npy')
pptNoList_05 = np.load(path+'pptNoList_05.npy')
autoCorr_05 = np.load(path+'autoCorr_05.npy')
autocorr060_05 = np.load(path+'autocorr060_05.npy')
autocorr3090_5 = np.load(path+'autocorr3090_5.npy')
areaDistList_5 = np.load(path+'areaDistList_5.npy',allow_pickle=True)

# C=3
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/HexagonalPlotData2/'

microStrNoList = np.load(path+'DmicroStrNoList.npy')
pptNoList = np.load(path+'pptNoList.npy')
autoCorr = np.load(path+'autoCorr.npy')
autocorr060 = np.load(path+'autocorr060.npy')
autocorr3090 = np.load(path+'autocorr3090.npy')
areaDistList_3 = np.load(path+'areaDistList.npy',allow_pickle=True)

# %%
mean = []
median =[]
mean4 = []
median4 =[]

for i in range(37):
    mean.append(np.mean(np.array(areaDistList_3[i])))
    median.append(np.median(np.array(areaDistList_3[i])))
    sortedList =np.sort(areaDistList_3[i][0:int(len(areaDistList_3[i])/2)]) 
    bins, edges = np.histogram(sortedList)
    left,right = edges[:-1],edges[1:]
    X = np.array([left,right]).T.flatten()
    Y = np.array([bins,bins]).T.flatten()
    plt.ylabel('No of Precipitates')
    plt.xlabel('Area')
    plt.title('Area distribution histogram, ppts='+str(int(len(areaDistList_3[i])/2)))
    plt.plot(X,Y,'g')
    
    mean4.append(np.mean(np.array(areaDistList_4[i])))
    median4.append(np.median(np.array(areaDistList_4[i])))
    sortedList =np.sort(areaDistList_4[i][0:int(len(areaDistList_4[i])/2)]) 
    bins, edges = np.histogram(sortedList )
    left,right = edges[:-1],edges[1:]
    X = np.array([left,right]).T.flatten()
    Y = np.array([bins,bins]).T.flatten()
    plt.ylabel('No of Precipitates')
    plt.xlabel('Area')
    plt.title('Area distribution histogram, ppts='+str(int(len(areaDistList_4[i])/2)))
    plt.plot(X,Y,'r')
    
#     mean5.append(np.mean(np.array(areaDistList_5[i])))
#     median5.append(np.median(np.array(areaDistList_5[i])))
#     sortedList =np.sort(areaDistList_5[i][0:int(len(areaDistList_5[i])/2)]) 
#     bins, edges = np.histogram(sortedList,)
#     left,right = edges[:-1],edges[1:]
#     X = np.array([left,right]).T.flatten()
#     Y = np.array([bins,bins]).T.flatten()
#     plt.ylabel('No of Precipitates')
#     plt.xlabel('Area')
#     plt.title('Area distribution histogram, ppts='+str(int(len(areaDistList_5[i])/2)))
#     plt.plot(X,Y,'g')
    plt.show()

# %%
plt.plot(mean,'g',label='c=0.3')
plt.plot(mean4,'r',label='c=0.4')
plt.title('Mean particle size')
plt.xlabel('time')
plt.ylabel('mean area')
plt.legend()
plt.show()

# %%
plt.plot(median,'g',label='c=0.3')
plt.plot(median4,'r',label='c=0.4')
plt.title('Median particle size')
plt.xlabel('time')
plt.ylabel('median area')
plt.legend()
plt.show()

# %%
mean = []
median =[]
for i in range(37):
    mean.append(np.mean(np.array(areaDistList_4[i])))
    median.append(np.median(np.array(areaDistList_4[i])))
    
    bins, edges = np.histogram((areaDistList_4[i]),bins=int((len(areaDistList_4[i]))))
    left,right = edges[:-1],edges[1:]
    X = np.array([left,right]).T.flatten()
    Y = np.array([bins,bins]).T.flatten()
    plt.ylabel('No of Precipitates')
    plt.xlabel('Area')
    plt.title('Area distribution histogram, ppts='+str(len(areaDistList_4[i])))
    plt.plot(X,Y,'r')
    plt.show()
    
mean = []
median =[]
for i in range(37):
    mean.append(np.mean(np.array(areaDistList_4[i])))
    median.append(np.median(np.array(areaDistList_4[i])))
    
    bins, edges = np.histogram(np.log10(areaDistList_4[i]),bins=int((len(areaDistList_4[i]))))
    left,right = edges[:-1],edges[1:]
    X = np.array([left,right]).T.flatten()
    Y = np.array([bins,bins]).T.flatten()
    plt.ylabel('No of Precipitates')
    plt.xlabel('Area')
    plt.title('log Area distribution histogram, ppts='+str(len(areaDistList_4[i])))
    plt.plot(X,Y,'g')
    plt.show()
    
 #***********   
mean = []
median =[]
for i in range(37):
    mean.append(np.mean(np.array(areaDistList_4[i])))
    median.append(np.median(np.array(areaDistList_4[i])))
    sot = np.sort(areaDistList_4[i])
    bins, edges = np.histogram(np.log10(sot[0:int(len(areaDistList_4[i])*3/4)]))
    left,right = edges[:-1],edges[1:]
    X = np.array([left,right]).T.flatten()
    Y = np.array([bins,bins]).T.flatten()
    plt.ylabel('No of Precipitates')
    plt.xlabel('Area')
    plt.title('logArea distribution histogram 3/4, ppts='+str(len(areaDistList_4[i])))
    plt.plot(X,Y,'b')
    plt.show()

# %%
for i in range(37):
    sot = np.sort(areaDistList_3[i])
    plt.plot(sot)
    plt.xlabel('particle number')
    plt.ylabel('area')
    plt.title('Plotting a sorted list of particle sizes')
    plt.show()

# %%
np.log10(2)
# Out:
# 0.3010299956639812
