# %% [markdown]
# # COMPARING ISO, HEX and CUB

# %% [markdown]
# # Importing all important scripts

# %%
import numpy as np
from PIL import Image
from Scripts import SpatialCorrelations as corr
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pymks
import pandas as pd
import os
from Scripts import velocityCalculations as vel
from Scripts import hoshenKopleman as hosh
import math
import time
from numpy import linalg as LA
from Scripts import plots

# %%
path = '/home/sushil/Desktop/adithya/ISOTROPIC/C03/'
list_of_files = os.listdir(path)
list_of_files.sort()
list_files = []
for i in list_of_files:
    if i[-5:]=='0.dat':
        list_files.append(path+i)

# %%
# Defining time
timeList = []
j = 0
for i in list_files:
    if j==3 or j%30==0 or j==10 or j==20:
        timeList.append(j*200)
    j = j+1

# %% [markdown]
# ## Reading Hexagonal

# %%
# C=3
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/HexagonalPlotData2/'

hex_microStrNoList = np.load(path+'DmicroStrNoList.npy')
hex_pptNoList = np.load(path+'pptNoList.npy')
hex_autoCorr = np.load(path+'autoCorr.npy')
hex_autocorr060 = np.load(path+'autocorr060.npy')
hex_autocorr3090 = np.load(path+'autocorr3090.npy')
hex_areaDistList = np.load(path+'areaDistList.npy',allow_pickle=True)

# C=4
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/HexagonalPlotData2/'

hex_microStrNoList_04 = np.load(path+'microStrNoList_04.npy')
hex_pptNoList_04 = np.load(path+'pptNoList_04.npy')
hex_autoCorr_04 = np.load(path+'autoCorr_04.npy')
hex_autocorr060_04 = np.load(path+'autocorr060_04.npy')
hex_autocorr3090_4 = np.load(path+'autocorr3090_4.npy')
hex_areaDistList_4 = np.load(path+'areaDistList_4.npy',allow_pickle=True)

# C=5
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/HexagonalPlotData2/'

hex_microStrNoList_05 = np.load(path+'microStrNoList_05.npy')
hex_pptNoList_05 = np.load(path+'pptNoList_05.npy')
hex_autoCorr_05 = np.load(path+'autoCorr_05.npy')
hex_autocorr060_05 = np.load(path+'autocorr060_05.npy')
hex_autocorr3090_5 = np.load(path+'autocorr3090_5.npy')
hex_areaDistList_5 = np.load(path+'areaDistList_5.npy',allow_pickle=True)

# C=3.5
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/HexagonalPlotData2/'

hex_microStrNoList35 = np.load(path+'DmicroStrNoList35.npy')
hex_pptNoList35 = np.load(path+'pptNoList35.npy')
hex_autoCorr35 = np.load(path+'autoCorr35.npy')
hex_autocorr06035 = np.load(path+'autocorr06035.npy')
hex_autocorr309035 = np.load(path+'autocorr309035.npy')
hex_areaDistList35 = np.load(path+'areaDistList35.npy',allow_pickle=True)

# C=45
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/HexagonalPlotData2/'

hex_microStrNoList_045 = np.load(path+'microStrNoList_045.npy')
hex_pptNoList_045 = np.load(path+'pptNoList_045.npy')
hex_autoCorr_045 = np.load(path+'autoCorr_045.npy')
hex_autocorr060_045 = np.load(path+'autocorr060_045.npy')
hex_autocorr3090_45 = np.load(path+'autocorr3090_45.npy')
hex_areaDistList_45 = np.load(path+'areaDistList_45.npy',allow_pickle=True)

# C=41
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/HexagonalPlotData2/'

hex_microStrNoList_041 = np.load(path+'microStrNoList_041.npy')
hex_pptNoList_041 = np.load(path+'pptNoList_041.npy')
hex_autoCorr_041 = np.load(path+'autoCorr_041.npy')
hex_autocorr060_041 = np.load(path+'autocorr060_041.npy')
hex_autocorr3090_41 = np.load(path+'autocorr3090_41.npy')
hex_areaDistList_41 = np.load(path+'areaDistList_41.npy',allow_pickle=True)

# C=42
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/HexagonalPlotData2/'

hex_microStrNoList_042 = np.load(path+'microStrNoList_042.npy')
hex_pptNoList_042 = np.load(path+'pptNoList_042.npy')
hex_autoCorr_042 = np.load(path+'autoCorr_042.npy')
hex_autocorr060_042 = np.load(path+'autocorr060_042.npy')
hex_autocorr3090_42 = np.load(path+'autocorr3090_42.npy')
hex_areaDistList_42 = np.load(path+'areaDistList_42.npy',allow_pickle=True)

# C=43
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/HexagonalPlotData2/'

hex_microStrNoList_043 = np.load(path+'microStrNoList_043.npy')
hex_pptNoList_043 = np.load(path+'pptNoList_043.npy')
hex_autoCorr_043 = np.load(path+'autoCorr_043.npy')
hex_autocorr060_043 = np.load(path+'autocorr060_043.npy')
hex_autocorr3090_43 = np.load(path+'autocorr3090_43.npy')
hex_areaDistList_43 = np.load(path+'areaDistList_43.npy',allow_pickle=True)

# %% [markdown]
# ## Reading Isotropic

# %%
# C=5
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/IsotropicPlotData/'

iso_microStrNoList_05 = np.load(path+'microStrNoList_05.npy')
iso_pptNoList_05 = np.load(path+'pptNoList_05.npy')
iso_autoCorr_05 = np.load(path+'autoCorr_05.npy')
iso_areaDistList_5 = np.load(path+'areaDistList_5.npy',allow_pickle=True)

# C=3
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/IsotropicPlotData/'

iso_microStrNoList = np.load(path+'microStrNoList.npy')
iso_pptNoList = np.load(path+'pptNoList.npy')
iso_autoCorr = np.load(path+'autoCorr.npy')
iso_areaDistList = np.load(path+'areaDistList.npy',allow_pickle=True)

# C=4
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/IsotropicPlotData/'

iso_microStrNoList_04 = np.load(path+'microStrNoList_04.npy')
iso_pptNoList_04 = np.load(path+'pptNoList_04.npy')
iso_autoCorr_04 = np.load(path+'autoCorr_04.npy')
iso_areaDistList_4 = np.load(path+'areaDistList_4.npy',allow_pickle=True)

# C=45
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/IsotropicPlotData/'

iso_microStrNoList45 = np.load(path+'microStrNoList45.npy')
iso_pptNoList45 = np.load(path+'pptNoList45.npy')
iso_autoCorr45 = np.load(path+'autoCorr45.npy')
iso_areaDistList45 = np.load(path+'areaDistList45.npy',allow_pickle=True)

# C=35
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/IsotropicPlotData/'

iso_microStrNoList35 = np.load(path+'microStrNoList35.npy')
iso_pptNoList35 = np.load(path+'pptNoList35.npy')
iso_autoCorr35 = np.load(path+'autoCorr35.npy')
iso_areaDistList35 = np.load(path+'areaDistList35.npy',allow_pickle=True)

# %% [markdown]
# ## Reading Cubic

# %%
# C=5
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/CubicPlotData/'

microStrNoList_05 = np.load(path+'microStrNoList_05.npy')
pptNoList_05 = np.load(path+'pptNoList_05.npy')
autoCorr_05 = np.load(path+'autoCorr_05.npy')
autocorr060_05 = np.load(path+'autocorr060_05.npy')
autocorr3090_5 = np.load(path+'autocorr3090_5.npy')
areaDistList_5 = np.load(path+'areaDistList_5.npy',allow_pickle=True)

# C=3
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/CubicPlotData/'

cub_microStrNoList = np.load(path+'microStrNoList.npy')
cub_pptNoList = np.load(path+'pptNoList.npy')
cub_autoCorr = np.load(path+'autoCorr.npy')
cub_autocorr060 = np.load(path+'autocorr060.npy')
cub_autocorr3090 = np.load(path+'autocorr3090.npy')
cub_cub_areaDistList = np.load(path+'areaDistList.npy',allow_pickle=True)

# C=4
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/CubicPlotData/'

cub_microStrNoList_04 = np.load(path+'microStrNoList_04.npy')
cub_pptNoList_04 = np.load(path+'pptNoList_04.npy')
cub_autoCorr_04 = np.load(path+'autoCorr_04.npy')
cub_autocorr060_04 = np.load(path+'autocorr060_04.npy')
cub_autocorr3090_4 = np.load(path+'autocorr3090_4.npy')
cub_areaDistList_4 = np.load(path+'areaDistList_4.npy',allow_pickle=True)

# C=45
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/CubicPlotData/'

cub_microStrNoList45 = np.load(path+'microStrNoList45.npy')
cub_pptNoList45 = np.load(path+'pptNoList45.npy')
cub_autoCorr45 = np.load(path+'autoCorr45.npy')
cub_areaDistList45 = np.load(path+'areaDistList45.npy',allow_pickle=True)

# C=35
path = '/home/sushil/Desktop/adithya/code/MicrostructureStatistics/CubicPlotData/'

cub_microStrNoList35 = np.load(path+'microStrNoList35.npy')
cub_pptNoList35 = np.load(path+'pptNoList35.npy')
cub_autoCorr35 = np.load(path+'autoCorr35.npy')
cub_areaDistList35 = np.load(path+'areaDistList35.npy',allow_pickle=True)
